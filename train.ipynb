# %%
import pandas as pd

# %%
df = pd.read_csv(r"E:\hackerearth\dataset\train.csv")

# %%
df.head(10)
# Out:
#    PRODUCT_ID                                              TITLE  \
# 0     1925202  ArtzFolio Tulip Flowers Blackout Curtain for D...
# 1     2673191  Marks & Spencer Girls' Pyjama Sets T86_2561C_N...
# 2     2765088  PRIKNIK Horn Red Electric Air Horn Compressor ...
# 3     1594019  ALISHAH Women's Cotton Ankle Length Leggings C...
# 4      283658  The United Empire Loyalists: A Chronicle of th...
# 5     2152929  HINS Metal Bucket Shape Plant Pot for Indoor &...
# 6      413758                      Ungifted: My Life and Journey
# 7     2026580  Delavala Self Adhesive Kitchen Backsplash Wall...
# 8     2050239  PUMA Cali Sport Clean Women's Sneakers White L...
# 9     2998633  Hexwell Essential oil for Home Fragrance Oil A...
#
#                                        BULLET_POINTS  \
# 0  [LUXURIOUS & APPEALING: Beautiful custom-made ...
# 1  [Harry Potter Hedwig Pyjamas (6-16 Yrs),100% c...
# 2  [Loud Dual Tone Trumpet Horn, Compatible With ...
# ...

# %%
df.isna().sum()
# Out:
# PRODUCT_ID               0
# TITLE                   12
# BULLET_POINTS       837364
# DESCRIPTION        1157381
# PRODUCT_TYPE_ID          0
# PRODUCT_LENGTH           0
# dtype: int64

# %%
X_train, X_test, Y_train, y_test = train_test_split(X, Y, test_size=testSize, random_state=42)
logger.info(X_train.shape)
#importing and fitting the model
import xgboost as xgb
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn import ensemble
#importing and fitting the models
Bagging_regr = BaggingRegressor(n_estimators = 500, random_state = 0)
Hist_gbr     = HistGradientBoostingRegressor(learning_rate=0.1, max_iter = 900, max_depth=9)
	xgb_regr     = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.2, max_depth = 6, alpha = 8, n_estimators = 500)
	gb_regr      = ensemble.GradientBoostingRegressor(n_estimators = 900, max_depth =8, min_samples_split=0.4, learning_rate = 0.1 )
	Bagging_regr.fit(X_train,Y_train)
	Hist_gbr.fit(X_train,Y_train)
	xgb_regr.fit(X_train,Y_train)
	gb_regr.fit(X_train,Y_train)
	#dumping the fitted models to .pkl files
	import pickle
	pickle.dump(Bagging_regr, open('/tmp/model_1.pkl','wb'))
	pickle.dump(Hist_gbr, open('/tmp/model_2.pkl','wb'))
	pickle.dump(xgb_regr, open('/tmp/model_3.pkl','wb'))
	pickle.dump(gb_regr, open('/tmp/model_4.pkl','wb'))
	#fetching values from environment variables/Serverless.yml
	ACCESS_KEY = os.environ['s3Key']
	SECRET_KEY = os.environ['s3Secret']
	BUCKET     = os.environ['s3Bucket']

	s3 = boto3.client("s3", 
							aws_access_key_id=ACCESS_KEY,
							aws_secret_access_key=SECRET_KEY)
	#uploading .pkl files to the valuation/bucket
	s3.upload_file('/tmp/train_data.pkl',BUCKET, 'valuation/train_data.pkl')
	s3.upload_file('/tmp/model_1.pkl',BUCKET, 'valuation/model_1.pkl')
	s3.upload_file('/tmp/model_2.pkl',BUCKET, 'valuation/model_2.pkl')
	s3.upload_file('/tmp/model_3.pkl',BUCKET, 'valuation/model_3.pkl')
	s3.upload_file('/tmp/model_4.pkl',BUCKET, 'valuation/model_4.pkl')
	
	#error margin
	#error margin
	

	p1     = Bagging_regr.predict(X_test)
	p2     = Hist_gbr.predict(X_test)
	p3     = xgb_regr.predict(X_test)
	p4     = gb_regr.predict(X_test)
# Out:
# <bound method Series.unique of 0          1650
# 1          2755
# 2          7537
# 3          2996
# 4          6112
#            ...
# 2249693    3009
# 2249694    3413
# 2249695    1574
# 2249696     592
# 2249697    7367
# Name: PRODUCT_TYPE_ID, Length: 2249698, dtype: int64>
